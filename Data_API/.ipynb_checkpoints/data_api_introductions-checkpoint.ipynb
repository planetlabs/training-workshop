# %% [markdown]
# # Planet Data API Introduction using Python
#
# ---

# %% [markdown]
# ## Introduction
#
# ---
#
# This tutorial is an introduction to [Planet](https://www.planet.com)'s Data API. It provides code samples on how to write simple Python code to access data.
#
# [`https://api.planet.com/data/v1`](https://api.planet.com/data/v1)
#
# The focus of this tutorial will be the search portion of the Planet Data API. We will find and download imagery data using complex searches and save them for later use, as well as learn how to get stats on search results. After completing this tutorial, you should feel comfortable interacting with the Data API, and have a good foundation for leveraging the Planet Data API for your own applications.

# %% [markdown]
# ## Table of Contents
#
# ---
#
# * **Introduction**
#     * Requirements
#        * Software & Modules
#        * Planet API Key
#     * Useful Links
#
#
# * **Overview**
#      * The Basic Workflow
#       * Data API Endpoints
#       * Planet Explorer
#
#
# * **Basic Setup**
#     * Authentication
#     * Helper Modules and Functions
#     * Our First Request
#
#
# * **Search Mechanics & Filters**
#     * Statistics
#     * Using a Search Filter
#     * Filter types
#         * Field Filters
#         * Logical Filters
#         * (Field) Filter Type examples
#     * Complex Queries using Logical Filters
#
#
# * **Searching for Items**
#     * Quick Search
#         * Mapping Footprints Example
#
#
# * **Assets & Permissions**
#     * Activating Assets
#     * Downloading Assets
#     * Rate Limits
#
#
# * **Saved Searches**
#
#
# * **Conclusion**

# %% [markdown]
# ### Requirements
#
# ---
#
# #### Software & Modules
#
# This tutorial assumes familiarity with the [Python](https://python.org) programming language throughout. Familiarity with basic REST API concepts and usage is also assumed.
#
# We'll be using a **"Jupyter Notebook"** (aka Python Notebook) to run through the examples.
# To learn more about and get started with using Jupyter, visit: [Jupyter](https://jupyter.org/) and [IPython](https://ipython.org/).
#
# For the best experience, download this notebook and run it on your system, and make sure to install the modules listed below first. You can also copy the examples' code to a separate Python files an run them directly with Python on your system if you prefer.
#
#
# Python modules used in this tutorial are:
# * [requests](http://docs.python-requests.org/)
# * [geojsonio](https://pypi.python.org/pypi/geojsonio)
#
#
# #### Planet API Key
#
# You should have an account on the Planet Platform to access the Data API. You may retrieve your API key from your [account page](https://www.planet.com/account/), or from the "API Tab" in [Planet Explorer](https://www.planet.com/explorer).

# %% [markdown]
# ### Useful links
#
# ---
#
# * [Planet Data API Reference & Documentation](https://www.planet.com/docs/reference/data-api/)
# * [Planet Explorer](https://www.planet.com/explorer)
#
# * Planet Data API explorer - Coming Soon!

# %% [markdown]
# ## Overview
#
# ---
#
# ### The Basic Workflow:
#
# 1. Search item types based on filters
# 1. Activate assets
# 1. Download assets

# %% [markdown]
# ### API Endpoints
#
# This tutorial will cover the following API ***endpoints***:
#
# * [`/item-types`](https://api.planet.com/data/v1/item-types/)
# * [`/asset-types`](https://api.planet.com/data/v1/asset-types/)
# * `/quick-search`
# * `/searches`
# * `/stats`
#
# There is an additional [`/spec`](https://api.planet.com/data/v1/spec) endpoint that publishes a [Swagger](http://swagger.io/) specification for the Data API.
#
# ### Exploring Endpoints
#
# We can start by exploring two endpoints using our browser.
#
# ##### What item types are available?
#
# https://api.planet.com/data/v1/item-types/
#
# ##### What assets are available?
#
# https://api.planet.com/data/v1/asset-types/

# %% [markdown]
# ***Note:*** *You may choose to install a helpful browser plugin called **JSONView** that formats JSON and makes it easier to read:*
#
# * [Chrome Extension](https://chrome.google.com/webstore/detail/jsonview/chklaanhfefbnpoihckbnefhakgolnmc)
# * [Firefox Plugin](https://addons.mozilla.org/en-us/firefox/addon/jsonview/)

# %% [markdown]
# ### Planet Explorer
# We can also use Planet Explorer to expose relevant API information for search results.
#
# In Planet Explorer, while in *Daily Imagery Mode* click on the *"Api"* button in the bottom left corner of the results panel.
#
# ![Planet Explorer Screenshot](images/planet-explorer.png)
#
# Here, you may access your API Key, selected item id's, and `cURL` request information containing filters and options.

# %% [markdown]
# ## Basic Setup
#
# ---
#
# Before interacting with the Planet Data API using Python, we will set up our environment with some useful modules and helper functions.
#
# * We'll configure *authentication* to the Planet Data API
# * We'll use the `requests` Python module to make HTTP communication easier.
# * We'll use the `json` Python module to help us work with JSON responses from the API.
# * We'll create a function called `p` that will print Python dictionaries nicely.
#
# Then we'll be ready to make our first call to the Planet API by hitting the base endpoint at `https://api.planet.com/data/v1`.
#
# Let's start by configuring authentication:

# %% [markdown]
# ### Authentication
#
# Authentication with the Planet Data API be achieved using a valid Planet **API key**.

# %% [markdown]
# You can *export* your API Key as an environment variable on your system:
#
# `export PL_API_KEY="YOUR API KEY HERE"`
#
# Or add the variable to your path, etc. If you are using our Docker environement, it will already be set.
#
# To start our Python code, we'll setup an API Key variable from an environment variable to use with our requests:

# %%
# Import the os module in order to access environment variables
import os

# If you're following along with this notebook, you can enter your API Key on the following line, and uncomment it:
#os.environ['PL_API_KEY']='YOUR API KEY HERE'

# Setup the API Key from the `PL_API_KEY` environment variable
PLANET_API_KEY = os.getenv('PL_API_KEY')

# %% [markdown]
# ### Helper Modules and Functions

# %%
# Import helper modules
import json
import requests

# %%
# Helper function to print formatted JSON using the json module
def p(data):
    print(json.dumps(data, indent=2))

# %% [markdown]
# ### Our First Request

# %%
# Setup Planet Data API base URL
URL = "https://api.planet.com/data/v1"

# Setup the session
session = requests.Session()

# Authenticate
session.auth = (PLANET_API_KEY, "")

# %%
# Make a GET request to the Planet Data API
res = session.get(URL)

# %% [markdown]
# Now we should get a response, hopefully it's a `200` code, saying everything is OK!

# %%
# Response status code
res.status_code
# Out:
# 200

# %%
# Response Body
res.text
# Out:
# '{"_links": {"_self": "https://api.planet.com/data/v1/", "asset-types": "https://api.planet.com/data/v1/asset-types/", "item-types": "https://api.planet.com/data/v1/item-types/", "spec": "https://api.planet.com/data/v1/spec"}}'

# %%
# Print formatted JSON response
p(res.json())
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/",
#     "asset-types": "https://api.planet.com/data/v1/asset-types/",
#     "item-types": "https://api.planet.com/data/v1/item-types/",
#     "spec": "https://api.planet.com/data/v1/spec"
#   }
# }

# %%
# Print the value of the item-types key from _links
print(res.json()["_links"]["_self"])
# Out:
# https://api.planet.com/data/v1/

# %% [markdown]
# **Congratulations!** You just made your first request to the Planet Data API using Python!
#
# Now, let's take a look at how to access all that high cadence satellite imagery!

# %% [markdown]
# ## Search Mechanics & Filters
#
# ---
#
# There's a lot of data available on the Planet Data API and in order to find what we're looking for, we'll have to perform various types of searches.
#
# To construct a search, we use **filters** that let us limit results based on date, geography or other metadata properties.
#
# Using these filters, we are able to **search** for items or get **statistics** for search results.
#
# Let's first make a request to the `/stats` endpoint to understand how the filters work:

# %% [markdown]
# ### Statistics `/stats`
#
# ---
#
# The `/stats` endpoint provides a summary of the available data based on some search criteria.
#
# `https://api.planet.com/data/v1/stats`
#
# We'll need to send a ***`POST`*** request to `/stats`, let's start by setting up the request url:

# %%
# Setup the stats URL
stats_url = "{}/stats".format(URL)

# Print the stats URL
print(stats_url)
# Out:
# https://api.planet.com/data/v1/stats

# %% [markdown]
# ### Using a Search Filter
#
# Search filters should have the following properties:
#
# * **Type** (`type`) - The type of filter being used
# * **Configuration** (`config`) - The configuration for this filter
# * **Field Name** (`field_name`) - The field on which to filter
#
# For this example, let's use a filter to get some stats on what data is available for *Planet Scope (3 Band)* and *Rapid Eye (Ortho Tile)* products taken from 2013 until now:

# %%
# Specify the sensors/satellites or "item types" to include in our results
item_types = ["PSScene"]

# %%
# Create filter object for all imagery captured between 2018-01-01 and present.
date_filter = {
    "type": "DateRangeFilter", # Type of filter -> Date Range
    "field_name": "acquired", # The field to filter on: "acquired" -> Date on which the "image was taken"
    "config": {
        "gte": "2018-01-01T00:00:00.000Z", # "gte" -> Greater than or equal to
    }
}

# %% [markdown]
# Depending on the filter type, some requests may need an `interval` field:
#
# The following intervals are possible:
# * `year`
# * `month`
# * `week`
# * `day`
# * `hour`
#
# An `interval` must be provided with the request so that the number of matching items can be aggregated. We'll use an interval with our date filter.

# %% [markdown]
# Now let's perform our request using the `date_filter` filter we created above:

# %%
# Construct the request.
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter
}

# Send the POST request to the API stats endpoint
res = session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 286300584,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 226985941,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 226296330,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 211955482,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 86877086,
#       "start_time": "2022-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# ***Good Job!*** You've received a response from the API that contains some statistics like item counts for the search criteria!

# %% [markdown]
# <div class="alert alert-info">
#
# **Exercise:** Create a new date filter to find data from before 2013.
#
# </div>

# %%
# Fill in this filter to complete the exercise! 
date_filter2 = {
}

request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter
}

res = session.post(stats_url, json=request)
p(res.json())

# %% [markdown]
# ---
#
# Next, let's take a closer look at some of the available filters:

# %% [markdown]
# ### Filter types
#
# The Planet Data API supports several filter types. The most common are the following:
#
# ### Field Filters
#
# * `DateRangeFilter`
# * `RangeFilter`
# * `StringInFilter`
# * `PermissionFilter`
# * `GeometryFilter`
#
# ### Logical Filters
#
# * `NotFilter`
# * `AndFilter`
# * `OrFilter`
#
# More information and examples on filter types can be found at the [API Docs](https://www.planet.com/docs/reference/data-api/search-api/).
#
# ---
#
# ### (Field) Filter Type examples:

# %% [markdown]
# #### `DateRangeFilter`
#
# Find imagery that was `acquired` or `published` before, after or between certain dates.
#
# ```
# {
#   "type": "DateRangeFilter",
#   "field_name": "acquired",
#   "config": {
#     "gt": "2016-01-01T00:00:00Z",
#     "lte": "2016-03-01T00:00:00Z"
#   }
# }
# ```
#
# The upper or lower bound may be omitted.

# %% [markdown]
# #### `RangeFilter`
#
# Find imagery that has a metadata that matches a number within a range of numbers.
#
# ```
# {
#   "type": "RangeFilter",
#   "field_name": "cloud_cover",
#   "config": {
#     "lt": 0.2,
#     "gt": 0.1
#   }
# }
# ```

# %% [markdown]
# The following **operators** are supported by the Data API's `DateRangeFilter` and `RangeFilter`:
# * `gt`: Greater Than
# * `gte`: Greater Than or Equal To
# * `lt`: Less Than
# * `lte`: Less Than or Equal To

# %% [markdown]
# #### `StringInFilter`
#
# Find imagery that has a metadata that matches a string within the array of provided strings.
#
#
# ```
# {
#   "type": "StringInFilter",
#   "field_name": "instrument",
#   "config": ["PS2"]
# }
# ```

# %% [markdown]
# #### `PermissionFilter`
#
# Find data which has assets that are accessible by the user.
#
# ```
# {
#   "type": "PermissionFilter",
#   "config": ["assets.analytic:download"]
# }
# ```
#
# ***Note:*** `assets:download` means *any* downloadable asset.

# %% [markdown]
# #### `GeometryFilter`
#
# Find data contained within a given geometry. The filter's config value may be any valid GeoJSON object.
#
# ```
# {
#   "type": "GeometryFilter",
#   "field_name": "geometry",
#   "config": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           -120.27282714843749,
#           38.348118547988065
#         ],
#         [
#           -120.27282714843749,
#           38.74337300148126
#         ],
#         [
#           -119.761962890625,
#           38.74337300148126
#         ],
#         [
#           -119.761962890625,
#           38.348118547988065
#         ],
#         [
#           -120.27282714843749,
#           38.348118547988065
#         ]
#       ]
#     ]
#   }
# }
# ```
#
# A few quick ways to get a GeoJSON geometry to use in your search:
#
# * Draw an Area of Interst (AOI) in [Planet Explorer](http://planet.com/explorer), and use the API button to see the geometry filter config.
# * Use your favorite GIS tools like [Quantum GIS (QGIS)](http://www.qgis.org) and export GeoJSON.
# * Draw a polygon in [GeoJSON.io](http://geojson.io).
#
# Make sure the `config` property in the geometry filter is in the right format, which should be similar to a `feature` property in a GeoJSON object.

# %% [markdown]
# ---
#
# Let's try a few more requests and get some more stats, this time using different filters:

# %%
# Search for imagery only from PlanetScope satellites that have a PS2 telescope

# Setup item types
item_types = ["PSScene"]

# Setup a filter for instrument type
instrument_filter = {
    "type": "StringInFilter",
    "field_name": "instrument",
    "config": ["PSB.SD"]
}

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : instrument_filter
}

# Send the POST request to the API stats endpoint
res = session.post(stats_url, json=request)

# Print response
p(res.json())

# %% [markdown]
# <div class="alert alert-info">
#
# **Exercise:** Create a new filter that finds all data from PS0 or PS1 telescopes.
#
# (!) There are some mistakes or missing fields on the current code
#
# </div>

# %%
# Fill in this filter to complete the exercise! 
instrument_filter2 = {}

request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : instrument_filter2
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())

# %% [markdown]
# Find a GeoJSON geometry from http://geojson.io and copy one `feature`.

# %%
# Search for imagery that only intersects with 40N, 90W

# Setup GeoJSON 
geom = {
    "type": "Point",
    "coordinates": [
        -90,
         40
    ]
}

# Setup Geometry Filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": geom
}

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "filter" : geometry_filter,
    "interval": "year"
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())

# %% [markdown]
# ### Complex Queries using Logical Filters
#
# Complex queries may require combining field filters using **logical filters** (see Filter Types above).
#
# Let's try a complex stats search:

# %%
# PS2 imagery; over 40N, 90W; captured between 2013 and present

# Setup an "AND" logical filter
and_filter = {
    "type": "AndFilter",
    "config": [instrument_filter, geometry_filter, date_filter]
}

# Print the logical filter
p(and_filter)
# Out:
# {
#   "type": "AndFilter",
#   "config": [
#     {
#       "type": "StringInFilter",
#       "field_name": "instrument",
#       "config": [
#         "PSB.SD"
#       ]
#     },
#     {
#       "type": "GeometryFilter",
#       "field_name": "geometry",
#       "config": {
#         "type": "Point",
#         "coordinates": [
#           -90,
#           40
#         ]
#       }
#     },
#     {
#       "type": "DateRangeFilter",
#       "field_name": "acquired",
#       "config": {
#         "gte": "2018-01-01T00:00:00.000Z"
#       }
#     }
#   ]
# }

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : and_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 72,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 292,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 216,
#       "start_time": "2022-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# Now that you're comfortable working with **filters**, let's take a look at how to perform searches!

# %% [markdown]
# ## Searching for Items
#
# ---
#
# There are two types of searches:
# * **"Quick Search"** `/quick-search`
# * **"Saved Searches"** `/searches`
#
# Saved searches are retained on the Planet Platform and may be performed again at any time in the future. You can use these to setup efficient workflows for repetitive tasks, for example, querying an area that is of interest to you, or getting data for specific sensors.
#
# Quick searches are meant to be more fleeting, and are not guaranteed to be available on the API after they are executed.
#
# Searches use the same request format as the `/stats` endpoint except without the `interval` field.

# %% [markdown]
# ### Quick Search
#
# Let's dive right in and create our first `quick search`:

# %%
# Setup the quick search endpoint url
quick_url = "{}/quick-search".format(URL)

# %%
# Setup Item Types
# item_types = ["PSScene"]

# Setup GeoJSON for only imagery that intersects with 40N, 90W
geom = {
    "type": "Point",
    "coordinates": [
        -90,
         40
    ]
}

# Setup a geometry filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": geom
}

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : geometry_filter
}

# %%
# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# Print the response
p(geojson)
# print(len(geojson["features"]))
# Out:
# {
#   "_links": {
#     "_first": "https://api.planet.com/data/v1/searches/ed2c99d91d654ec0bf8b86257bd6089d/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#     "_next": "https://api.planet.com/data/v1/searches/ed2c99d91d654ec0bf8b86257bd6089d/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIyLTAxLTA0VDIyOjU5OjQ2LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjIwMTA0XzE1NTMxNl81MV8yNDM1IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#     "_self": "https://api.planet.com/data/v1/searches/ed2c99d91d654ec0bf8b86257bd6089d/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
#   },
#   "features": [
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220919_161225_71_2276",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220919_161225_71_2276/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220919_161225_71_2276/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.27881267500628,
#               40.07636276815281
#             ],
#             [
#               -90.3300484596365,
#               39.89880197248377
#             ],
#             [
#               -89.94336704680462,
#               39.83191512839856
#             ],
#             [
#               -89.89090164528518,
#               40.009760809847286
#             ],
#             [
#               -90.27881267500628,
#               40.07636276815281
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220919_161225_71_2276",
#       "properties": {
#         "acquired": "2022-09-19T16:12:25.718214Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 79,
#         "clear_percent": 39,
#         "cloud_cover": 0.57,
#         "cloud_percent": 57,
#         "ground_control": true,
#         "gsd": 3.8,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-09-20T02:55:52Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 276

#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220903_155313_94_2434/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220903_155313_94_2434/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.05452857612943,
#               40.04696347154911
#             ],
#             [
#               -90.10839409102554,
#               39.86030633336532
#             ],
#             [
#               -89.70191668616704,
#               39.78949143255677
#             ],
#             [
#               -89.64623868818352,
#               39.97649868106968
#             ],
#             [
#               -90.05452857612943,
#               40.04696347154911
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220903_155313_94_2434",
#       "properties": {
#         "acquired": "2022-09-03T15:53:13.943179Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 92,
#         "clear_percent": 90,
#         "cloud_cover": 0.05,
#         "cloud_percent": 1,
#         "ground_control": true,
#         "gsd": 4,
#         "heavy_haze_percent": 4,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 5,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-09-04T01:15:21Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 277.7,
#         "satellite_id": "2434",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5902563",
#         "sun_azimuth": 130.2,
#         "sun_elevation": 46.8,
#         "updated": "2022-09-04T04:25:20Z",
#         "view_angle": 4,
#         "visible_confidence_percent": 68,
#         "visible_percent": 95
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220903_155311_64_2434",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220903_155311_64_2434/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220903_155311_64_2434/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
# ...
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 101.1,
#         "satellite_id": "2429",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5274869",
#         "sun_azimuth": 147.4,
#         "sun_elevation": 21,
#         "updated": "2022-01-11T05:54:16Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 66,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220109_164257_49_2406",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220109_164257_49_2406/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220109_164257_49_2406/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.1822936234493,
#               40.03198980659564
#             ],
#             [
#               -90.23423525584867,
#               39.8427036588501
#             ],
#             [
#               -89.82322223100596,
#               39.775714352600794
#             ],
#             [
#               -89.7702494602038,
#               39.963309100965105
#             ],
#             [
#               -90.1822936234493,
#               40.03198980659564
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220109_164257_49_2406",
#       "properties": {
#         "acquired": "2022-01-09T16:42:57.490604Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 91,
#         "clear_percent": 95,
#         "cloud_cover": 0.01,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 4,
#         "heavy_haze_percent": 1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 3,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-01-10T03:15:54Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 101.2,
#         "satellite_id": "2406",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5272273",
#         "sun_azimuth": 158.9,
#         "sun_elevation": 25.3,
#         "updated": "2022-01-11T05:49:05Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 62,
#         "visible_percent": 99
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220109_164255_19_2406",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220109_164255_19_2406/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220109_164255_19_2406/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.14274220939843,
#               40.17551505054542
#             ],
#             [
#               -90.19482343657097,
#               39.986217426757065
#             ],
#             [
#               -89.78292084510936,
#               39.91918123444199
#             ],
#             [
#               -89.72981169195465,
#               40.10676041950269
#             ],
#             [
#               -90.14274220939843,
#               40.17551505054542
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220109_164255_19_2406",
#       "properties": {
#         "acquired": "2022-01-09T16:42:55.198964Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 93,
#         "clear_percent": 96,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 4,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 3,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-01-10T03:15:54Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 101.2,
#         "satellite_id": "2406",
#         "shadow_percent": 0,
#         "snow_ice_percent": 1,
#         "strip_id": "5272273",
#         "sun_azimuth": 159,
#         "sun_elevation": 25.1,
#         "updated": "2022-01-11T05:48:36Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 63,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220106_155622_81_2449",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220106_155622_81_2449/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220106_155622_81_2449/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.0374115163976,
#               40.14663936039906
#             ],
#             [
#               -90.09337176570989,
#               39.95868945064544
#             ],
#             [
#               -89.68240110521604,
#               39.88532156135409
#             ],
#             [
#               -89.62490819354699,
#               40.073853722995075
#             ],
#             [
#               -90.0374115163976,
#               40.14663936039906
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220106_155622_81_2449",
#       "properties": {
#         "acquired": "2022-01-06T15:56:22.816957Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 35,
#         "clear_percent": 5,
#         "cloud_cover": 0.53,
#         "cloud_percent": 13,
#         "ground_control": true,
#         "gsd": 4.1,
#         "heavy_haze_percent": 40,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 42,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-01-07T00:48:33Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 278.4,
#         "satellite_id": "2449",
#         "shadow_percent": 0,
#         "snow_ice_percent": 1,
#         "strip_id": "5263140",
#         "sun_azimuth": 147.8,
#         "sun_elevation": 20.4,
#         "updated": "2022-01-07T06:12:57Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 43,
#         "visible_percent": 47
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220104_155318_81_2435",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220104_155318_81_2435/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220104_155318_81_2435/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.19874288326506,
#               40.07760654757353
#             ],
#             [
#               -90.25152364940682,
#               39.887969098848515
#             ],
#             [
#               -89.83984677220532,
#               39.82017957602358
#             ],
#             [
#               -89.7862675025158,
#               40.00781246450807
#             ],
#             [
#               -90.19874288326506,
#               40.07760654757353
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220104_155318_81_2435",
#       "properties": {
#         "acquired": "2022-01-04T15:53:18.813195Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 57,
#         "clear_percent": 7,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 4.1,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-01-04T22:59:46Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 100.9,
#         "satellite_id": "2435",
#         "shadow_percent": 0,
#         "snow_ice_percent": 93,
#         "strip_id": "5256624",
#         "sun_azimuth": 148.1,
#         "sun_elevation": 20.6,
#         "updated": "2022-01-05T05:11:20Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 54,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220104_155316_51_2435",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220104_155316_51_2435/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220104_155316_51_2435/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.15911987969506,
#               40.22151973908035
#             ],
#             [
#               -90.2121652925779,
#               40.031948494518126
#             ],
#             [
#               -89.79963774629279,
#               39.9640381831707
#             ],
#             [
#               -89.74579076700333,
#               40.15158666685469
#             ],
#             [
#               -90.15911987969506,
#               40.22151973908035
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220104_155316_51_2435",
#       "properties": {
#         "acquired": "2022-01-04T15:53:16.511674Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 44,
#         "clear_percent": 0,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 4.1,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-01-04T22:59:46Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 101,
#         "satellite_id": "2435",
#         "shadow_percent": 0,
#         "snow_ice_percent": 100,
#         "strip_id": "5256624",
#         "sun_azimuth": 148.2,
#         "sun_elevation": 20.5,
#         "updated": "2022-01-05T05:11:50Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 56,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     }
#   ],
#   "type": "FeatureCollection"
# }

# %% [markdown]
# Nice! The response gives us search results for Planet Scope (4 Band) for a specific area.
#
# Let's do another search, this time using the "instrument" filter we setup earlier:

# %%
# Setup Item Types
item_types = ["PSScene"]

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : instrument_filter
}

# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# Print the response
p(geojson)
# Out:
# {
#   "_links": {
#     "_first": "https://api.planet.com/data/v1/searches/dcb96d9da79d4c30aa73f3c04b0c645f/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#     "_next": "https://api.planet.com/data/v1/searches/dcb96d9da79d4c30aa73f3c04b0c645f/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIyLTA5LTIxVDEzOjQzOjU4LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjIwOTIxXzA3NDQyMl82Nl8yNDQ5IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#     "_self": "https://api.planet.com/data/v1/searches/dcb96d9da79d4c30aa73f3c04b0c645f/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
#   },
#   "features": [
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_051448_33_2475",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_051448_33_2475/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220921_051448_33_2475/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               73.58774451037588,
#               15.380828749089028
#             ],
#             [
#               73.55047609358199,
#               15.19627266934583
#             ],
#             [
#               73.86821529413466,
#               15.133285788810866
#             ],
#             [
#               73.90607063293156,
#               15.318980469352843
#             ],
#             [
#               73.58774451037588,
#               15.380828749089028
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220921_051448_33_2475",
#       "properties": {
#         "acquired": "2022-09-21T05:14:48.335376Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 77,
#         "clear_percent": 90,
#         "cloud_cover": 0.08,
#         "cloud_percent": 8,
#         "ground_control": false,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-09-21T13:45:10Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 276.9,
#         "satellite_id": "2475",
#         "shadow_percent": 2,
#         "snow_ice_percent": 0,
#         "strip_id": "5944255",
#         "sun_azimuth": 116.9,
#         "sun_elevation": 60.2,
#         "updated": "2022-09-21T13:45:10Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 63,
#         "visible_percent": 92
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_051258_63_2475",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_051258_63_2475/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220921_051258_63_2475/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               75.0636908803709,
#               22.290398106100092
#             ],
#             [
#               75.02407830151743,
#               22.106445294189633
#             ],
#             [
#               75.3545651063419,
#               22.0422465093481
#             ],
#             [
#               75.39503983750191,
#               22.227296484370477
#             ],
#             [
#               75.0636908803709,
#               22.290398106100092
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220921_051258_63_2475",
#       "properties": {
#         "acquired": "2022-09-21T05:12:58.637039Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent":
2475",
#       "properties": {
#         "acquired": "2022-09-21T05:12:31.212455Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 78,
#         "clear_percent": 62,
#         "cloud_cover": 0.17,
#         "cloud_percent": 5,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 11,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 21,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-09-21T13:45:09Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "satellite_azimuth": 277,
#         "satellite_id": "2475",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5944255",
#         "sun_azimuth": 130.1,
#         "sun_elevation": 56.5,
#         "updated": "2022-09-21T13:45:09Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 62,
#         "visible_percent": 83
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_051226_64_2475",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_051226_64_2475/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220921_051226_64_2475/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               75.51326424513675,
#               24.30288483470382
#             ],
#             [
#               75.4727030618327,
#               24.119152832252706
#             ],
#             [
#               75.80796452651339,
#               24.054529213344402
#             ],
#             [
#               75.84951226476423,
#               24.23932965681113
#             ],
#             [
#               75.51326424513675,
#               24.30288483470382
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220921_051226_64_2475",
#       "properties": {
#         "acquired": "2022-09-21T05:12:26.641691Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 88,
#         "clear_percent": 95,
#         "cloud_cover": 0.02,
#         "cloud_percent": 2,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 3,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-09-21T13:45:09Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "satellite_azimuth": 276.8,
#         "satellite_id": "2475",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5944255",
#         "sun_azimuth": 130.5,
#         "sun_elevation": 56.3,
#         "updated": "2022-09-21T13:45:09Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 67,
#         "visible_percent": 98
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_051222_07_2475",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_051222_07_2475/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220921_051222_07_2475/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               75.57739869398273,
#               24.589463220719527
#             ],
#             [
#               75.53670236896428,
#               24.405744604619894
#             ],
#             [
#               75.87286099880392,
#               24.341053038975623
#             ],
#             [
#               75.91442890464727,
#               24.525873003579033
#             ],
#             [
#               75.57739869398273,
#               24.589463220719527
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220921_051222_07_2475",
#       "properties": {
#         "acquired": "2022-09-21T05:12:22.070927Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 79,
#         "clear_percent": 82,
#         "cloud_cover": 0.11,
#         "cloud_percent": 8,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 3,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 6,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-09-21T13:45:09Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "satellite_azimuth": 277,
#         "satellite_id": "2475",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5944255",
#         "sun_azimuth": 130.9,
#         "sun_elevation": 56.1,
#         "updated": "2022-09-21T13:45:09Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 57,
#         "visible_percent": 89
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_051217_50_2475",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_051217_50_2475/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220921_051217_50_2475/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               75.64206038875169,
#               24.875341460846244
#             ],
#             [
#               75.6012784944267,
#               24.691652100229486
#             ],
#             [
#               75.93825136285852,
#               24.626933991535797
#             ],
#             [
#               75.97992506278958,
#               24.811748938583634
#             ],
#             [
#               75.64206038875169,
#               24.875341460846244
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220921_051217_50_2475",
#       "properties": {
#         "acquired": "2022-09-21T05:12:17.500163Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 90,
#         "clear_percent": 98,
#         "cloud_cover": 0.02,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-09-21T13:45:09Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "satellite_azimuth": 277.2,
#         "satellite_id": "2475",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5944255",
#         "sun_azimuth": 131.3,
#         "sun_elevation": 56,
#         "updated": "2022-09-21T13:45:09Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 76,
#         "visible_percent": 98
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_051212_92_2475",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_051212_92_2475/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220921_051212_92_2475/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               75.70821523894368,
#               25.16473330838179
#             ],
#             [
#               75.66717572667285,
#               24.981046087611507
#             ],
#             [
#               76.00491730330167,
#               24.91616037159862
#             ],
#             [
#               76.04687425988084,
#               25.100947897465808
#             ],
#             [
#               75.70821523894368,
#               25.16473330838179
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220921_051212_92_2475",
#       "properties": {
#         "acquired": "2022-09-21T05:12:12.929399Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 90,
#         "clear_percent": 95,
#         "cloud_cover": 0.05,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 4,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 1,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-09-21T13:45:09Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "satellite_azimuth": 276.9,
#         "satellite_id": "2475",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5944255",
#         "sun_azimuth": 131.6,
#         "sun_elevation": 55.8,
#         "updated": "2022-09-21T13:45:09Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 64,
#         "visible_percent": 95
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_051208_35_2475",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_051208_35_2475/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220921_051208_35_2475/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               75.77383352927616,
#               25.451691519221452
#             ],
#             [
#               75.73266354383593,
#               25.26797613336699
#             ],
#             [
#               76.0712143992151,
#               25.20301683834818
#             ],
#             [
#               76.11329633143033,
#               25.387810430771232
#             ],
#             [
#               75.77383352927616,
#               25.451691519221452
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220921_051208_35_2475",
#       "properties": {
#         "acquired": "2022-09-21T05:12:08.358635Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 92,
#         "clear_percent": 100,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-09-21T13:45:09Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "satellite_azimuth": 277,
#         "satellite_id": "2475",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5944255",
#         "sun_azimuth": 132,
#         "sun_elevation": 55.7,
#         "updated": "2022-09-21T13:45:09Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 69,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_051154_64_2475",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_051154_64_2475/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220921_051154_64_2475/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               75.97147174083217,
#               26.31403321422355
#             ],
#             [
#               75.92985603603405,
#               26.130391324864963
#             ],
#             [
#               76.27086453386731,
#               26.065187109429292
#             ],
#             [
#               76.31343959298833,
#               26.24991378066613
#             ],
#             [
#               75.97147174083217,
#               26.31403321422355
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220921_051154_64_2475",
#       "properties": {
#         "acquired": "2022-09-21T05:11:54.646343Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 94,
#         "clear_percent": 93,
#         "cloud_cover": 0.04,
#         "cloud_percent": 3,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 2,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 2,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-09-21T13:45:09Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "satellite_azimuth": 277,
#         "satellite_id": "2475",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5944255",
#         "sun_azimuth": 133.1,
#         "sun_elevation": 55.2,
#         "updated": "2022-09-21T13:45:09Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 66,
#         "visible_percent": 96
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_051002_66_2475",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_051002_66_2475/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220921_051002_66_2475/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               77.64337113113726,
#               33.34107280020244
#             ],
#             [
#               77.5942489828168,
#               33.173306658217285
#             ],
#             [
#               77.91967062664769,
#               33.11413740405161
#             ],
#             [
#               77.98296294604806,
#               33.27905668079661
#             ],
#             [
#               77.64337113113726,
#               33.34107280020244
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220921_051002_66_2475",
#       "properties": {
#         "acquired": "2022-09-21T05:10:02.662625Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 52,
#         "clear_percent": 4,
#         "cloud_cover": 0.95,
#         "cloud_percent": 95,
#         "ground_control": false,
#         "gsd": 3.6,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-09-21T13:45:09Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 277.4,
#         "satellite_id": "2475",
#         "shadow_percent": 1,
#         "snow_ice_percent": 0,
#         "strip_id": "5944255",
#         "sun_azimuth": 141.1,
#         "sun_elevation": 50.7,
#         "updated": "2022-09-21T13:45:09Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 57,
#         "visible_percent": 5
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_050958_09_2475",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_050958_09_2475/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220921_050958_09_2475/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               77.71390452089842,
#               33.626523224793466
#             ],
#             [
#               77.6324029620023,
#               33.468929018074526
#             ],
#             [
#               78.01255427692834,
#               33.39555940262414
#             ],
#             [
#               78.05366359966216,
#               33.564769784414956
#             ],
#             [
#               77.71390452089842,
#               33.626523224793466
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220921_050958_09_2475",
#       "properties": {
#         "acquired": "2022-09-21T05:09:58.091861Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 67,
#         "clear_percent": 6,
#         "cloud_cover": 0.92,
#         "cloud_percent": 92,
#         "ground_control": false,
#         "gsd": 3.6,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-09-21T13:45:09Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 277.5,
#         "satellite_id": "2475",
#         "shadow_percent": 1,
#         "snow_ice_percent": 1,
#         "strip_id": "5944255",
#         "sun_azimuth": 141.4,
#         "sun_elevation": 50.5,
#         "updated": "2022-09-21T13:45:09Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 59,
#         "visible_percent": 8
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_050955_80_2475",
# ...
#               22.22586568393269,
#               -17.585319059213365
#             ],
#             [
#               21.894628308095353,
#               -17.519797186994722
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220921_074434_12_2449",
#       "properties": {
#         "acquired": "2022-09-21T07:44:34.123781Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 94,
#         "clear_percent": 99,
#         "cloud_cover": 0.01,
#         "cloud_percent": 1,
#         "ground_control": true,
#         "gsd": 4,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-09-21T13:43:59Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "satellite_azimuth": 96.8,
#         "satellite_id": "2449",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5944247",
#         "sun_azimuth": 69,
#         "sun_elevation": 46.9,
#         "updated": "2022-09-21T13:43:59Z",
#         "view_angle": 4.9,
#         "visible_confidence_percent": 71,
#         "visible_percent": 99
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_074431_83_2449",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_074431_83_2449/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220921_074431_83_2449/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               21.92549917376415,
#               -17.37581684111891
#             ],
#             [
#               21.884867793528052,
#               -17.56560396724898
#             ],
#             [
#               22.216503253688437,
#               -17.629662296430933
#             ],
#             [
#               22.256478239320803,
#               -17.441330757603822
#             ],
#             [
#               21.92549917376415,
#               -17.37581684111891
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220921_074431_83_2449",
#       "properties": {
#         "acquired": "2022-09-21T07:44:31.831621Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 91,
#         "clear_percent": 98,
#         "cloud_cover": 0.01,
#         "cloud_percent": 1,
#         "ground_control": true,
#         "gsd": 4,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-09-21T13:43:59Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "satellite_azimuth": 96.8,
#         "satellite_id": "2449",
#         "shadow_percent": 1,
#         "snow_ice_percent": 0,
#         "strip_id": "5944247",
#         "sun_azimuth": 69.2,
#         "sun_elevation": 46.9,
#         "updated": "2022-09-21T13:43:59Z",
#         "view_angle": 4.9,
#         "visible_confidence_percent": 65,
#         "visible_percent": 99
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_074429_53_2449",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_074429_53_2449/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220921_074429_53_2449/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               21.956453743489465,
#               -17.232055506512257
#             ],
#             [
#               21.915907683654172,
#               -17.421838616911216
#             ],
#             [
#               22.2472913435308,
#               -17.485816230397674
#             ],
#             [
#               22.287189105178594,
#               -17.297468633528187
#             ],
#             [
#               21.956453743489465,
#               -17.232055506512257
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220921_074429_53_2449",
#       "properties": {
#         "acquired": "2022-09-21T07:44:29.539461Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 91,
#         "clear_percent": 97,
#         "cloud_cover": 0.02,
#         "cloud_percent": 2,
#         "ground_control": true,
#         "gsd": 4,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-09-21T13:43:59Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "satellite_azimuth": 96.7,
#         "satellite_id": "2449",
#         "shadow_percent": 1,
#         "snow_ice_percent": 0,
#         "strip_id": "5944247",
#         "sun_azimuth": 69.3,
#         "sun_elevation": 47,
#         "updated": "2022-09-21T13:43:59Z",
#         "view_angle": 4.9,
#         "visible_confidence_percent": 63,
#         "visible_percent": 98
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_074427_24_2449",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_074427_24_2449/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220921_074427_24_2449/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               21.987240047447255,
#               -17.088241816617025
#             ],
#             [
#               21.946805544458247,
#               -17.278042814109043
#             ],
#             [
#               22.27796481910474,
#               -17.34189360868937
#             ],
#             [
#               22.31774126589863,
#               -17.153551743206556
#             ],
#             [
#               21.987240047447255,
#               -17.088241816617025
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220921_074427_24_2449",
#       "properties": {
#         "acquired": "2022-09-21T07:44:27.247301Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 87,
#         "clear_percent": 87,
#         "cloud_cover": 0.11,
#         "cloud_percent": 11,
#         "ground_control": true,
#         "gsd": 4,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-09-21T13:43:59Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "satellite_azimuth": 96.6,
#         "satellite_id": "2449",
#         "shadow_percent": 2,
#         "snow_ice_percent": 0,
#         "strip_id": "5944247",
#         "sun_azimuth": 69.4,
#         "sun_elevation": 47.1,
#         "updated": "2022-09-21T13:43:59Z",
#         "view_angle": 4.9,
#         "visible_confidence_percent": 61,
#         "visible_percent": 89
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_074424_95_2449",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_074424_95_2449/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220921_074424_95_2449/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               22.017858923893893,
#               -16.94415391711483
#             ],
#             [
#               21.97746627410615,
#               -17.13394006787053
#             ],
#             [
#               22.30838940448404,
#               -17.19774389432815
#             ],
#             [
#               22.348090397513797,
#               -17.00939506844674
#             ],
#             [
#               22.017858923893893,
#               -16.94415391711483
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220921_074424_95_2449",
#       "properties": {
#         "acquired": "2022-09-21T07:44:24.955141Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 92,
#         "clear_percent": 91,
#         "cloud_cover": 0.08,
#         "cloud_percent": 8,
#         "ground_control": true,
#         "gsd": 4,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-09-21T13:43:59Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "satellite_azimuth": 96.8,
#         "satellite_id": "2449",
#         "shadow_percent": 1,
#         "snow_ice_percent": 0,
#         "strip_id": "5944247",
#         "sun_azimuth": 69.5,
#         "sun_elevation": 47.2,
#         "updated": "2022-09-21T13:43:59Z",
#         "view_angle": 4.9,
#         "visible_confidence_percent": 63,
#         "visible_percent": 92
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_074422_66_2449",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_074422_66_2449/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220921_074422_66_2449/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               22.047716431015342,
#               -16.800159344719532
#             ],
#             [
#               22.007364211974853,
#               -16.98994588387421
#             ],
#             [
#               22.33799784910991,
#               -17.053776228370428
#             ],
#             [
#               22.377695302840152,
#               -16.865440610241958
#             ],
#             [
#               22.047716431015342,
#               -16.800159344719532
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220921_074422_66_2449",
#       "properties": {
#         "acquired": "2022-09-21T07:44:22.662981Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 93,
#         "clear_percent": 100,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 4,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-09-21T13:43:58Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "satellite_azimuth": 96.8,
#         "satellite_id": "2449",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5944247",
#         "sun_azimuth": 69.7,
#         "sun_elevation": 47.2,
#         "updated": "2022-09-21T13:43:58Z",
#         "view_angle": 4.9,
#         "visible_confidence_percent": 70,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     }
#   ],
#   "type": "FeatureCollection"
# }

# %% [markdown]
# Let's take a closer look at our response data:

# %%
# Assign a features variable 
features = geojson["features"]

# Get the number of features present in the response
len(features)
# Out:
# 250

# %%
# Let's paginate
while "_next" in geojson.get("_links"):
    page_url = geojson.get("_links")["_next"]
    r = session.post(quick_url, json=request)
    geojson = r.json()
    features += geojson["features"]
    
    # For now, let's add an arbitrary limit
    limit = 1000
    if len(features) >= limit:
        break

# %%
# Again, Get the number of features present in the response
len(features)
# Out:
# 1000

# %%
# Loop over all the features from the response
# for f in features[:40]:
    # Print the ID for each feature
    # p(f["id"])
    
print(",".join(['"{}"'.format(i["id"]) for i in features[0:20]]))
# Out:
# "20220921_051448_33_2475","20220921_051258_63_2475","20220921_051254_06_2475","20220921_051249_49_2475","20220921_051244_92_2475","20220921_051240_35_2475","20220921_051235_78_2475","20220921_051231_21_2475","20220921_051226_64_2475","20220921_051222_07_2475","20220921_051217_50_2475","20220921_051212_92_2475","20220921_051208_35_2475","20220921_051154_64_2475","20220921_051002_66_2475","20220921_050958_09_2475","20220921_050955_80_2475","20220921_050951_23_2475","20220921_050946_66_2475","20220921_050944_37_2475"

# %%
# Print the first feature
p(features[23])
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_050932_95_2475",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220921_050932_95_2475/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220921_050932_95_2475/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           78.09880504775157,
#           35.19959776608012
#         ],
#         [
#           78.04505579162497,
#           35.04393498216945
#         ],
#         [
#           78.36344656998064,
#           34.98634264507825
#         ],
#         [
#           78.4045967289842,
#           35.14050461391557
#         ],
#         [
#           78.09880504775157,
#           35.19959776608012
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20220921_050932_95_2475",
#   "properties": {
#     "acquired": "2022-09-21T05:09:32.952659Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 51,
#     "clear_percent": 14,
#     "cloud_cover": 0.86,
#     "cloud_percent": 84,
#     "ground_control": false,
#     "gsd": 3.2,
#     "heavy_haze_percent": 2,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 1,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2022-09-21T13:45:08Z",
#     "publishing_stage": "preview",
#     "quality_category": "test",
#     "satellite_azimuth": 277.7,
#     "satellite_id": "2475",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "5944255",
#     "sun_azimuth": 143,
#     "sun_elevation": 49.5,
#     "updated": "2022-09-21T13:45:08Z",
#     "view_angle": 5,
#     "visible_confidence_percent": 55,
#     "visible_percent": 14
#   },
#   "type": "Feature"
# }

# %% [markdown]
# What happens when there are A LOT of results?
#
# When the number of matching items exceeds 250, the results are delivered in pages. Let's perform a search query that should return a large number of results:

# %%
# Setup a GeoJSON polygon for our geometry filter -> geojson.io is a good friend
geom = {
    "type": "Polygon",
    "coordinates":[
          [
            [
              -0.23139953613281247,
              50.78987674433805
            ],
            [
              -0.04875183105468749,
              50.78987674433805
            ],
            [
              -0.04875183105468749,
              50.87487785990267
            ],
            [
              -0.23139953613281247,
              50.87487785990267
            ],
            [
              -0.23139953613281247,
              50.78987674433805
            ]
          ]
        ]
  }

# Setup the geometry filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": geom
}

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : geometry_filter
}

# %%
# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# %%
# Print the response "_links" property
p(geojson["_links"])
# Out:
# {
#   "_first": "https://api.planet.com/data/v1/searches/a1edfbd492ad46c0a1cf2542093e3084/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#   "_next": "https://api.planet.com/data/v1/searches/a1edfbd492ad46c0a1cf2542093e3084/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIyLTA2LTI4VDE5OjUwOjE5LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjIwNjI4XzEwMzgxNV8yNF8yNGE1IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#   "_self": "https://api.planet.com/data/v1/searches/a1edfbd492ad46c0a1cf2542093e3084/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
# }

# %%
# Assign the "_links" -> "_next" property (link to next page of results) to a variable 
next_url = geojson["_links"]["_next"]

# Print the link to the next page of results
print(next_url)
# Out:
# https://api.planet.com/data/v1/searches/a1edfbd492ad46c0a1cf2542093e3084/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIyLTA2LTI4VDE5OjUwOjE5LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjIwNjI4XzEwMzgxNV8yNF8yNGE1IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319

# %% [markdown]
# The page size can be set with a `_page_size` parameter in the request:

# %%
# Send the POST request to the API quick search endpoint with a page size of 9
res = session.post(quick_url, json=request, params={"_page_size" : 10})
# print(res.text)

# Assign the response to a variable
geojson = res.json()

# Get the number of features present in the response
len(geojson["features"])
# Out:
# 10

# %% [markdown]
# ### Mapping Footprints Example
#
# The [`geojsonio`](https://pypi.python.org/pypi/geojsonio/) module can be used to map GeoJSON files and is therefore compatible with the output from Planet Data API searches.
#
# Make sure you've got the module installed and then let's use it to show our resuls on a map:

# %%
# Import the geojsonio python module
# You may need to install this on your system first
import geojsonio

# Assign the url variable to display the geojsonio map
url = geojsonio.display(res.text)

# %% [markdown]
# We can now iterate through the pages of results.

# %%
# Assign the next_url variable to the next page of results from the response (Setup the next page of results)
next_url = geojson["_links"]["_next"]

# Get the next page of results
res = session.get(next_url)

# Assign the response to a variable
geojson = res.json()

# Get the url see results on geojson.io
url = geojsonio.to_geojsonio(res.text)

# %%
# Setup the next page of results
next_url = geojson["_links"]["_next"]

# Get the next page of results
res = session.get(next_url)

# Assign the response to a variable
geojson = res.json()

# Get the url see results on geojson.io
url = geojsonio.to_geojsonio(res.text)

# %% [markdown]
# Cool huh? Now that we know how to search and find items we are interested in, let's try activating and downloading some assets.

# %% [markdown]
# ## Assets & Permissions
#
# Assets may be imagery files, image masks, metadata files or some other file type that might be associated with the item.
#
# The `_permissions` element in each feature contains a list of assets that the user has access to.

# %% [markdown]
# Let's pick the first item out of our search result to work with, and then see what the permissions are for that item:

# %%
# Assign a variable to the search result features (items)
features = geojson["features"]

# Get the first result's feature
feature = features[0]

# Print the ID
p(feature["id"])

# Print the permissions
p(feature["_permissions"])

# %% [markdown]
# Each item has an `assets` endpoint in the API that lists all of its assets. Let's get a list of available assets for our item:

# %%
# Get the assets link for the item
assets_url = feature["_links"]["assets"]

# Print the assets link
print(assets_url)

# %%
# Send a GET request to the assets url for the item (Get the list of available assets for the item)
res = session.get(assets_url)

# Assign a variable to the response
assets = res.json()

# %%
# Print the asset types that are available
print(assets.keys())

# %% [markdown]
# We can see that most items have several assets available. Let's check out the "visual" asset for this item:

# %%
# Assign a variable to the visual asset from the item's assets
udm2 = assets["ortho_udm2"]

# Print the visual asset data
p(udm2)

# %% [markdown]
# ### Activating Assets
#
# Before an asset is available for download, it must be **activated**.
#
# You can activate an asset by sending a *POST* or *GET* request to the asset's **"activation link"**.
#
# The activation usually takes a little bit of time, but hey, I'm sure by now you have some ideas on how to automate your workflow. Go robots!

# %%
# Setup the activation url for a particular asset (in this case the visual asset)
activation_url = udm2["_links"]["activate"]

# Send a request to the activation url to activate the item
res = session.get(activation_url)

# Print the response from the activation request
p(res.status_code)

# %% [markdown]
# #### Activation Response Codes
#
# After hitting an activation url, you should get a response code back from the API:
#
# * **`202`** - The request has been accepted and the activation will begin shortly.
# * **`204`** - The asset is already active and no further action is needed.
# * **`401`** - The user does not have permissions to download this file.

# %% [markdown]
# After requesting to actiate an asset, let's do another request to see if the assset's status has changed:

# %%
import time

asset_activated = False

while asset_activated == False:
    # Send a request to the item's assets url
    res = session.get(assets_url)

    # Assign a variable to the item's assets url response
    assets = res.json()

    # Assign a variable to the visual asset from the response
    udm2 = assets["ortho_udm2"]

    asset_status = udm2["status"]
        
    # If asset is already active, we are done
    if asset_status == 'active':
        asset_activated = True
        print("Asset is active and ready to download")
    else:
        print("Asset status is: {} ".format(asset_status))
        time.sleep(10)

# Print the UDM2 asset data    
p(udm2)

# %% [markdown]
# #### Activation Status
#
# An asset may have a `status` of `inactive`, `activating` or `active`.
#
# Once an asset is active, the response will contain a `location`. We'll use the `location` to download the asset!
#
# Below, we are polling the API until the item is activated. This may take awhile.

# %% [markdown]
# ### Downloading Assets
#
# The asset's `location` property points asset file for use to download. Are you ready to download the asset? Let's do it!

# %%
# Assign a variable to the visual asset's location endpoint
location_url = udm2["location"]

# Print the location endpoint
print(location_url)

# %% [markdown]
# There's the location url! You could click on it to open it in a browser and download the file... but why not let your code do it?
#
# Let's write a small helper function to download asset files:

# %%
# Create a function to download asset files
# Parameters: 
# - url (the location url)
# - filename (the filename to save it as. defaults to whatever the file is called originally)

def pl_download(url, filename=None):
    
    # Send a GET request to the provided location url, using your API Key for authentication
    res = requests.get(url, stream=True, auth=(PLANET_API_KEY, ""))
    # If no filename argument is given
    if not filename:
        # Construct a filename from the API response
        if "content-disposition" in res.headers:
            filename = res.headers["content-disposition"].split("filename=")[-1].strip("'\"")
        # Construct a filename from the location url
        else:
            filename = url.split("=")[1][:10]
    # Save the file
    with open('output/' + filename, "wb") as f:
        for chunk in res.iter_content(chunk_size=1024):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)
                f.flush()

    return filename

# %%
# Download the file from an activated asset's location url
pl_download(location_url)

# %% [markdown]
# **High Five!** You should now be downloading your very own GeoTIFF! We can't wait to see what you'll do with it!

# %% [markdown]
# ### Rate Limits
#
# ---
#
# Now that you know how to download assets, you should probably keep some of the API **rate limits** in mind:
#
# * For most endpoints, the rate limit is 10 requests per second, per API key.
# * For activation endpoints, the rate limit is 5 requests per second, per API key.
# * For download endpoints, the rate limit is 15 requests per second, per API key.
#
# If you're writing to code to automate accessing the API, you should account for `429` responses and handle retries after a *backoff period*.

# %% [markdown]
# ## Saved Searches
#
# ---
#
# The `/searches` endpoint lets you created saved searches that can be reused.
#
# To view your saved searches, visit the [`searches/?search_type=saved`](https://api.planet.com/data/v1/searches/?search_type=saved) endpoint.
#
# Finally, let's create a saved search:

# %%
# Setup the saved searches endpoint url
searches_url = "{}/searches".format(URL)

# %%
# Setup the request, specifying a name for the saved search, along with the usual search item_types and filter.
request = {
    "name" : "Vancouver Island",
    "item_types" : item_types,
    "filter" : geometry_filter
}

# Send a POST request to the saved searches endpoint (Create the saved search)
res = session.post(searches_url, json=request)

# Print the response
p(res.json())
# Out:
# {
#   "__daily_email_enabled": false,
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/searches/dfe048f2f68c4cd39579ad6916d16d96",
#     "results": "https://api.planet.com/data/v1/searches/dfe048f2f68c4cd39579ad6916d16d96/results"
#   },
#   "created": "2022-09-21T14:04:31.788935Z",
#   "filter": {
#     "config": {
#       "coordinates": [
#         [
#           [
#             -0.23139953613281247,
#             50.78987674433805
#           ],
#           [
#             -0.04875183105468749,
#             50.78987674433805
#           ],
#           [
#             -0.04875183105468749,
#             50.87487785990267
#           ],
#           [
#             -0.23139953613281247,
#             50.87487785990267
#           ],
#           [
#             -0.23139953613281247,
#             50.78987674433805
#           ]
#         ]
#       ],
#       "type": "Polygon"
#     },
#     "field_name": "geometry",
#     "type": "GeometryFilter"
#   },
#   "id": "dfe048f2f68c4cd39579ad6916d16d96",
#   "item_types": [
#     "PSScene"
#   ],
#   "last_executed": null,
#   "name": "Vancouver Island",
#   "search_type": "saved",
#   "updated": "2022-09-21T14:04:31.788935Z"
# }

# %% [markdown]
# Now that we created a saved search, let's get a list of our saved searches:

# %%
# Send a GET request to the saved searches endpoint with the saved search type parameter (Get saved searches)
res = session.get(searches_url, params={"search_type" : "saved"})

# Assign a variable to the searches property in the saved searches response
searches = res.json()["searches"]
print(searches)#['name'])
print(len(searches))

# Loop through the searches
for search in searches:
    # Print the ID, Created Time, and Name for each saved search
    print("id: {} created: {} name: {}".format(search["id"], search["created"], search['name']))
# Out:
# [{'__daily_email_enabled': False, '_links': {'_self': 'https://api.planet.com/data/v1/searches/dfe048f2f68c4cd39579ad6916d16d96', 'results': 'https://api.planet.com/data/v1/searches/dfe048f2f68c4cd39579ad6916d16d96/results'}, 'created': '2022-09-21T14:04:31.788935Z', 'filter': {'config': {'coordinates': [[[-0.23139953613281247, 50.78987674433805], [-0.04875183105468749, 50.78987674433805], [-0.04875183105468749, 50.87487785990267], [-0.23139953613281247, 50.87487785990267], [-0.23139953613281247, 50.78987674433805]]], 'type': 'Polygon'}, 'field_name': 'geometry', 'type': 'GeometryFilter'}, 'id': 'dfe048f2f68c4cd39579ad6916d16d96', 'item_types': ['PSScene'], 'last_executed': None, 'name': 'Vancouver Island', 'search_type': 'saved', 'updated': '2022-09-21T14:04:31.788935Z'}, {'__daily_email_enabled': True, '_links': {'_self': 'https://api.planet.com/data/v1/searches/c0da19d0fe204cdaaed290d34eaf1a0a', 'results': 'https://api.planet.com/data/v1/searches/c0da19d0fe204cdaaed290d34eaf1a0a/results'}, 'created': '2022-08-17T09:53:21.865627Z', 'filter': {'config': [{'config': {'coordinates': [[[-117.008809, 36.435602], [-116.845901, 36.435602], [-116.845901, 36.578536], [-117.008809, 36.578536], [-117.008809, 36.435602]]], 'type': 'Polygon'}, 'field_name': 'geometry', 'type': 'GeometryFilter'}, {'config': [{'config': {'gte': '2022-07-01T00:00:00Z'}, 'field_name': 'acquired', 'type': 'DateRangeFilter'}], 'type': 'OrFilter'}, {'config': [{'config': [{'config': [{'config': ['PSScene'], 'field_name': 'item_type', 'type': 'StringInFilter'}, {'config': [{'config': ['basic_analytic_4b'], 'type': 'AssetFilter'}], 'type': 'AndFilter'}], 'type': 'AndFilter'}], 'type': 'AndFilter'}], 'type': 'OrFilter'}, {'config': ['assets:download'], 'type': 'PermissionFilter'}], 'type': 'AndFilter'}, 'id': 'c0da19d0fe204cdaaed290d34eaf1a0a', 'item_types': ['PSScene'], 'last_executed': None, 'name': 'Death Valley floods', 'search_type': 'saved', 'updated': '2022-08-19T13:18:41.371067Z'}]
# 2
# id: dfe048f2f68c4cd39579ad6916d16d96 created: 2022-09-21T14:04:31.788935Z name: Vancouver Island
# id: c0da19d0fe204cdaaed290d34eaf1a0a created: 2022-08-17T09:53:21.865627Z name: Death Valley floods

# %% [markdown]
# Ok, now let's check out the results from a particular saved search:

# %%
# Setup the saved search url, using the first saved search in the list
saved_url = "{}/{}".format(searches_url, searches[0]["id"])

# Print the saved search url
p(saved_url)

# Setup the saved search's results url
results_url = "{}/results".format(saved_url)

# Print the saved search's results url
p(results_url)

# %%
# Send a GET request to the saved search url (Get the saved search data)
res = session.get(saved_url)

# Print the response
p(res.json())

# %%
# Send a GET request to the saved search results url (Get the saved search results)
results = session.get(results_url).json()

# Print the number of features in the saved search
print(len(results["features"]))

# Print the first feature in the saved search
print(results["features"][0])

# %% [markdown]
# A saved search can also be updated by senidng a **`PUT`** request with a changed search definition back to the API.
#
# Did you know that saved searches can also send you a daily email to alert you to when new items are added to the search resutlts? Oh yeah!

# %%
# Assign a variable to the saved search response
search = res.json()

# Print the saved search
p(search)

# %%
# Change the saved search name to "South Vancouver Island"
search["name"] = "South Vancouver Island"

# Set the daily email enabled to true (Get email alerts when new items show up in this search)
search["__daily_email_enabled"] = True

# Send a PUT request to the saved search endpoint (Update the saved search)
res = session.put(saved_url, json=search)

# The response status code
res.status_code

# %% [markdown]
# ## Conclusion
#
# You made it! You should now be able to use the Planet API to find items and assets by searching, get stats and save searches, and activate and download assets using Python code!
#
# Don't forget to visit the [Planet API Reference Docs](https://www.planet.com/docs/reference/).
