# %% [markdown]
# # Usable Data Mask (UDM2) Visualization and Masking
#
# The Usable Data Mask (UDM2) is an iteration upon the Unusable Data Mask (UDM) product. It is available for many products and it contains the UDM as one of its bands. Specifications for the UDM2 are given in the [Imagery Spec Sheet](https://assets.planet.com/docs/combined-imagery-product-spec-april-2019.pdf) and the [UDM-2 API documentation](https://developers.planet.com/docs/api/udm-2/).
#
# The UDM2 is a multi-band image. The first six bands are boolean bands that encode the absence or presence of different image usability concerns such as haze, clouds, and cloud shadows. The sixth band provides the confidence in the usability assessments as integer values between 0 and 100. The seventh band is the Unusable Data Mask, which is described in the Imagery Spec Sheet referenced above.
#
# In this notebook, we demonstrate how to visualize the UDM2 bands and how to convert the UDM2 into two masks: masking all unclear pixels and masking cloud and shadow pixels.

# %% [markdown]
# ## Install Dependencies and Set up Notebook

# %%
from collections import namedtuple, OrderedDict
import os

import matplotlib
import matplotlib.colors as colors
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import numpy as np
import rasterio

# %matplotlib inline

# %% [markdown]
# ## Define and Visualize Scene
#
# The UDM2 asset is available for the `PSScene4Band` item-type. Not all PSScene4Band scenes have a UDM2 asset, so here we define the scene and item-type for the UDM2 asset.

# %%
scene_id = '20190321_174348_0f1a'
item_type = 'PSScene4Band'

# %% [markdown]
# If you do not have your Planet API key set as an environment variable yet, let's do just that.

# %%
os.environ["PL_API_KEY"] = 'YOUR PLANET API KEY'

# %% [markdown]
# ## Visualize Metadata
#
# Visualize the metadata for the scene `PSScene4Band` item-type.

# %%
# uncomment to see metadata fields
# !planet data search --item-type $item_type --string-in id $scene_id
# Out:
# {
#   "features": [
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190321_174348_0f1a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20190321_174348_0f1a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20190321_174348_0f1a/thumb"
#       },
#       "_permissions": [
#         "assets.udm:download",
#         "assets.analytic:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_udm:download",
#         "assets.analytic_sr:download",
#         "assets.basic_udm2:download",
#         "assets.udm2:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -122.21049154391311,
#               37.79557520832023
#             ],
#             [
#               -122.47650538906952,
#               37.751472239757746
#             ],
#             [
#               -122.49448069032667,
#               37.820052189572344
#             ],
#             [
#               -122.22829066393206,
#               37.86402829115282
#             ],
#             [
#               -122.22500288108917,
#               37.85123970277374
#             ],
#             [
#               -122.22478695907967,
#               37.851275337560125
#             ],
#             [
#               -122.21049154391311,
#               37.79557520832023
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20190321_174348_0f1a",
#       "properties": {
#         "acquired": "2019-03-21T17:43:48.206517Z",
#         "anomalous_pixels": 0,
#         "clear_percent": 94,
#         "cloud_cover": 0.02,
#         "cloud_percent": 4,
#         "columns": 8340,
#         "epsg_code": 32610,
#         "ground_control": true,
#         "gsd": 3.6,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 544491,
#         "origin_y": 4191012,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2019-03-22T02:02:08.898Z",
#         "quality_category": "standard",
#         "rows": 4215,
#         "satellite_id": "0f1a",
#         "strip_id": "2221943",
#         "sun_azimuth": 127.7,
#         "sun_elevation": 38.7,
#         "updated": "2019-03-22T08:15:04.982Z",
#         "usable_data": 0,
#         "view_angle": 1
#       },
#       "type": "Feature"
#     }
#   ],
#   "type": "FeatureCollection"
# }

# %% [markdown]
# Someday, fields will be added to the item `properties` that will allow for filtering on UDM2 values. Examples are `clear_percent` and `cloud_percent`. See the [WIP UDM2 documentation](http://planet-developer-center-website.s3-website-us-west-2.amazonaws.com/6d1845612d76a722f1e268e40cf88d2ecc6595e3/docs/api/udm-2/) for more fields. These metadata fields aren't yet present, so we will skip search and filtering of the UDM2 for now.

# %% [markdown]
# ## Visualize Scene

# %%
# create the data folder if it doesn't exist
data_folder = 'data'
if not os.path.isdir(data_folder): os.mkdir(data_folder)

# %%
# !planet data download --item-type $item_type \
                      --asset-type basic_analytic \
                      --string-in id $scene_id \
                      --dest data
# Out:
# activating: 0            complete: 0              elapsed: 0
# paging: False            pending: 0
#
# activating: 0            complete: 0              elapsed: 1
# paging: False            pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 2               paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 2               paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 0.00MB
# downloading: 1           elapsed: 3               paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 0.00MB
# downloading: 1           elapsed: 4               paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 0.00MB
# downloading: 1           elapsed: 5               paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 0.00MB
# downloading: 1           elapsed: 6               paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 0.52MB
# downloading: 1           elapsed: 7               paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 1.77MB
# downloading: 1           elapsed: 8               paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 2.88MB
# downloading: 1           elapsed: 9               paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 4.00MB
# downloading: 1           elapsed: 10              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 5.47MB
# downloading: 1           elapsed: 11              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 6.91MB
# downloading: 1           elapsed: 12              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 7.80MB
# downloading: 1           elapsed: 13              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 9.50MB
# downloading: 1           elapsed: 14              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 11.40MB
# downloading: 1           elapsed: 15              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 13.27MB
# downloading: 1           elapsed: 16              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 14.02MB
# downloading: 1           elapsed: 17              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 14.65MB
# downloading: 1           elapsed: 18              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 15.89MB
# downloading: 1           elapsed: 19              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 17.10MB
# downloading: 1           elapsed: 20              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 18.19MB
# downloading: 1           elapsed: 21              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 19.40MB
# downloading: 1           elapsed: 22              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 20.09MB
# downloading: 1           elapsed: 23              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 21.14MB
# downloading: 1           elapsed: 24              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 22.51MB
# downloading: 1           elapsed: 25              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 23.72MB
# downloading: 1           elapsed: 26              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 25.17MB
# downloading: 1           elapsed: 27              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 26.74MB
# downloading: 1           elapsed: 28              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 28.64MB
# downloading: 1           elapsed: 29              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 29.56MB
# downloading: 1           elapsed: 30              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 31.46MB
# downloading: 1           elapsed: 31              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 32.93MB
# downloading: 1           elapsed: 32              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 32.93MB
# downloading: 1           elapsed: 33              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 34.64MB
# downloading: 1           elapsed: 34              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 36.24MB
# downloading: 1           elapsed: 35              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 36.31MB
# downloading: 1           elapsed: 36              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 37.95MB
# downloading: 1           elapsed: 37              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 39.26MB
# downloading: 1           elapsed: 38              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 40.70MB
# downloading: 1           elapsed: 39              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 42.83MB
# downloading: 1           elapsed: 40              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 44.20MB
# downloading: 1           elapsed: 41              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 45.88MB
# downloading: 1           elapsed: 42              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 47.19MB
# downloading: 1           elapsed: 43              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 47.94MB
# downloading: 1           elapsed: 44              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 48.37MB
# downloading: 1           elapsed: 45              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 50.23MB
# downloading: 1           elapsed: 46              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 51.09MB
# downloading: 1           elapsed: 47              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 51.97MB
# downloading: 1           elapsed: 48              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 53.67MB
# downloading: 1           elapsed: 49              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 54.98MB
# downloading: 1           elapsed: 50              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 56.26MB
# downloading: 1           elapsed: 51              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 57.31MB
# downloading: 1           elapsed: 52              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 58.85MB
# downloading: 1           elapsed: 53              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 59.87MB
# downloading: 1           elapsed: 54              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 61.34MB
# downloading: 1           elapsed: 55              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 62.55MB
# downloading: 1           elapsed: 56              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 63.77MB
# downloading: 1           elapsed: 57              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 64.23MB
# downloading: 1           elapsed: 58              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 65.93MB
# downloading: 1           elapsed: 59              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 67.80MB
# downloading: 1           elapsed: 60              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 69.50MB
# downloading: 1           elapsed: 61              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 70.45MB
# downloading: 1           elapsed: 62              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 71.27MB
# downloading: 1           elapsed: 63              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 72.94MB
# downloading: 1           elapsed: 64              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 73.76MB
# downloading: 1           elapsed: 65              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 74.68MB
# downloading: 1           elapsed: 66              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 75.04MB
# downloading: 1           elapsed: 67              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 75.92MB
# downloading: 1           elapsed: 68              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 78.09MB
# downloading: 1           elapsed: 69              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 78.77MB
# downloading: 1           elapsed: 70              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 80.02MB
# downloading: 1           elapsed: 71              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 81.56MB
# downloading: 1           elapsed: 72              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 82.41MB
# downloading: 1           elapsed: 73              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 83.59MB
# downloading: 1           elapsed: 74              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 85.59MB
# downloading: 1           elapsed: 75              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 87.33MB
# downloading: 1           elapsed: 76              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 88.83MB
# downloading: 1           elapsed: 77              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 90.18MB
# downloading: 1           elapsed: 78              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 91.65MB
# downloading: 1           elapsed: 79              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 93.36MB
# downloading: 1           elapsed: 80              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 95.22MB
# downloading: 1           elapsed: 81              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 97.09MB
# downloading: 1           elapsed: 82              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 98.57MB
# downloading: 1           elapsed: 83              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 99.88MB
# downloading: 1           elapsed: 84              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 100.34MB
# downloading: 1           elapsed: 85              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 101.38MB
# downloading: 1           elapsed: 86              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 103.55MB
# downloading: 1           elapsed: 87              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 104.30MB
# downloading: 1           elapsed: 88              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 105.97MB
# downloading: 1           elapsed: 89              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 106.69MB
# downloading: 1           elapsed: 90              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 108.10MB
# downloading: 1           elapsed: 91              paging: False
# pending: 0
# 2019-12-10 14:40:13,253 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# {"item": "20190321_174348_0f1a", "asset": "basic_analytic", "location": "/Users/luisperaza/code/training-workshop/data/20190321_174348_0f1a_1B_AnalyticMS.tif"}

# %%
# store the scene filename for processing and make sure the file exists
scene_filename = os.path.join('data', scene_id + '_1B_AnalyticMS.tif')
print(scene_filename)
assert os.path.isfile(scene_filename)
# Out:
# data/20190321_174348_0f1a_1B_AnalyticMS.tif

# %%
# Utility functions: loading an image

NamedBands = namedtuple('NamedBands', 'b, g, r, nir')

def load_masked_bands(filename):
    """Loads a 4-band BGRNir Planet Image file as a list of masked bands.
    
    The masked bands share the same mask, so editing one band mask will
    edit them all."""
    with rasterio.open(filename) as src:
        b, g, r, nir = src.read()
        mask = src.read_masks(1) == 0 # 0 value means the pixel is masked
    
    bands = NamedBands(b=b, g=g, r=r, nir=nir)
    return NamedBands(*[np.ma.array(b, mask=mask)
                        for b in bands])

print(load_masked_bands(scene_filename).b.shape)
# Out:
# /Users/luisperaza/anaconda3/envs/support-tools/lib/python3.6/site-packages/rasterio/__init__.py:216: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, **kwargs)
# (2136, 6582)

# %%
# Utility functions: displaying an image

def _linear_scale(ndarray, old_min, old_max, new_min, new_max):
    """Linear scale from old_min to new_min, old_max to new_max.
    
    Values below min/max are allowed in input and output.
    Min/Max values are two data points that are used in the linear scaling.
    """
    #https://en.wikipedia.org/wiki/Normalization_(image_processing)
    return (ndarray - old_min)*(new_max - new_min)/(old_max - old_min) + new_min
# print(linear_scale(np.array([1,2,10,100,256,2560, 2660]), 2, 2560, 0, 256))

def _mask_to_alpha(bands):
    band = np.atleast_3d(bands)[...,0]
    alpha = np.zeros_like(band)
    alpha[~band.mask] = 1
    return alpha

def _add_alpha_mask(bands):
    return np.dstack([bands, _mask_to_alpha(bands)])

def bands_to_display(bands, alpha=True):
    """Converts a list of bands to a 3-band rgb, normalized array for display."""
    rgb_bands = np.dstack(bands[:3])

    old_min = np.percentile(rgb_bands, 2)
    old_max = np.percentile(rgb_bands, 98)
    new_min = 0
    new_max = 1
    scaled = _linear_scale(rgb_bands.astype(np.double),
                           old_min, old_max, new_min, new_max)
    bands = np.clip(scaled, new_min, new_max)
    if alpha is True:
        bands = _add_alpha_mask(bands)
    return bands

# %%
fig = plt.figure(figsize=(10, 10))
bands = load_masked_bands(scene_filename)
plt.imshow(bands_to_display([bands.r, bands.g, bands.b]))

plt.title('Scene')
ax = plt.axis('off')

# %% [markdown]
# ## Download UDM2
#
# To download the UDM2, we use the planet CLI because it handles activating, waiting for activation, and downloading the file.
#
# We will save the UDM2 in the data folder. This folder isn't tracked by git so the downloaded image file will not bloat our git repository.

# %%
# !planet data download --item-type $item_type \
                      --asset-type udm2 \
                      --string-in id $scene_id \
                      --dest data
# Out:
# activating: 0            complete: 0              elapsed: 0
# paging: False            pending: 0
#
# activating: 0            complete: 0              elapsed: 1
# paging: False            pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 2               paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 3               paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 4               paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 5               paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 6               paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 7               paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 8               paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 9               paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 10              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 11              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 12              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 13              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 14              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 15              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 16              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 17              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 18              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 19              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 20              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 21              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 22              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 23              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 24              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 25              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 26              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 27              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 28              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 29              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 30              paging: False
# pending: 0
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 31              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 32              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 33              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 34              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 35              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 36              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 37              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 38              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 39              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 40              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 41              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 42              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 43              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 44              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 45              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 46              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 47              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 48              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 49              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 50              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 51              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 52              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 53              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 54              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 55              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 56              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 57              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 58              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 59              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 60              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 61              paging: False
# pending: 0
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 62              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 63              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 64              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 65              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 66              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 67              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 68              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 69              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 70              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 71              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 72              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 73              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 74              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 75              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 76              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 77              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 78              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 79              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 80              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 81              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 82              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 83              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 84              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 85              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 86              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 87              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 88              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 89              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 90              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 91              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 92              paging: False
# pending: 0
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 93              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 94              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 95              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 96              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 97              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 98              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 99              paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 100             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 101             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 102             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 103             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 104             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 105             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 106             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 107             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 108             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 109             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 110             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 111             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 112             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 113             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 114             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 115             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 116             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 117             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 118             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 119             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 120             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 121             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 122             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 123             paging: False
# pending: 0
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 124             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 125             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 126             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 127             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 128             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 129             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 130             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 131             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 132             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 133             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 134             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 135             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 136             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 137             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 138             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 139             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 140             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 141             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 142             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 143             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 144             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 145             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 146             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 147             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 148             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 149             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 150             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 151             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 152             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 153             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 154             paging: False
# pending: 0
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 155             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 156             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 157             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 158             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 159             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 160             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 161             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 162             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 163             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 164             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 165             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 166             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 167             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 168             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 169             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 170             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 171             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 172             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 173             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 174             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 175             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 176             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 177             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 178             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 179             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 180             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 181             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 182             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 183             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 184             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 185             paging: False
# pending: 0
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 186             paging: False
# pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 187             paging: False
# pending: 0
# 2019-12-10 14:48:02,980 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 0.00MB
# downloading: 1           elapsed: 187             paging: False
# pending: 0
# 2019-12-10 14:48:02,980 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 0.00MB
# downloading: 1           elapsed: 188             paging: False
# pending: 0
# 2019-12-10 14:48:02,980 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 0.00MB
# downloading: 1           elapsed: 189             paging: False
# pending: 0
# 2019-12-10 14:48:02,980 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 0.03MB
# downloading: 1           elapsed: 190             paging: False
# pending: 0
# 2019-12-10 14:48:02,980 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 0.26MB
# downloading: 1           elapsed: 191             paging: False
# pending: 0
# 2019-12-10 14:48:02,980 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# activating: 0            complete: 0              downloaded: 1.08MB
# downloading: 1           elapsed: 192             paging: False
# pending: 0
# 2019-12-10 14:48:02,980 - FuturesSession - WARNING - `background_callback` is
# deprecated and will be removed in 1.0, use `hooks` instead
# {"item": "20190321_174348_0f1a", "asset": "udm2", "location": "/Users/luisperaza/code/training-workshop/data/20190321_174348_0f1a_3B_udm2.tif"}

# %%
# store the udm2 filename for processing and make sure the file exists
udm2_filename = os.path.join('data', scene_id + '_3B_udm2.tif')
print(udm2_filename)
assert os.path.isfile(udm2_filename)
# Out:
# data/20190321_174348_0f1a_3B_udm2.tif

# %% [markdown]
# ## Load UDM2
#
# In this section, we implement functionality for loading the UDM2 and identifying the bands. We load the UDM2 used in this notebook and determine the percentage of pixels that are clear of any usability concerns.

# %%
# Utility functions for loading a UDM2 image and identify bands as
# class labels
def load_udm2(udm2_filename):
    '''Load multi-band UDM2 as a 3d array.'''
    with rasterio.open(udm2_filename, 'r') as src:
        udm2 = src.read()
    return udm2

udm2_labels = ['clear', 'snow', 'shadow', 'light haze', 'heavy haze', 'cloud',
               'confidence', 'unusable pixels']

udm2 = load_udm2(udm2_filename)
print(udm2.shape)
print(udm2_labels)
# Out:
# (8, 4213, 8341)
# ['clear', 'snow', 'shadow', 'light haze', 'heavy haze', 'cloud', 'confidence', 'unusable pixels']

# %%
num_pixels = np.size(udm2[0,:])
num_clear = np.count_nonzero(udm2[0,:])
            
percent_clear = 100 * (num_pixels - num_clear) / num_pixels
print("{0:.01f}% of pixels are considered 'clear'".format(percent_clear))
# Out:
# 44.4% of pixels are considered 'clear'

# %% [markdown]
# # Visualize UDM2

# %% [markdown]
# ### Visualizing a Classified Band
#
# In this section we develop the capability to visualize a classified band, as UDM2 bands are classified bands.

# %%
def plot_classified_band(class_band, class_labels=None,
                         cmap='rainbow',
                         title='Class Labels', figdim=10):

    fig = plt.figure(figsize=(figdim, figdim))
    ax = fig.add_subplot(1, 1, 1)
    imshow_class_band(ax, class_band, class_labels=class_labels, cmap=cmap)
    ax.set_title(title)
    ax.set_axis_off()

def imshow_class_band(ax, class_band, class_labels=None, cmap='rainbow'):
    """Show classified band with colormap normalization and color legend.
    Alters ax in place.
    
    possible cmaps ref:
    https://matplotlib.org/examples/color/colormaps_reference.html
    """
    class_norm = _ClassNormalize(class_band)
    im = ax.imshow(class_band, cmap=cmap, norm=class_norm)

    try:
        # add class label legend
        # https://stackoverflow.com/questions/25482876
        # /how-to-add-legend-to-imshow-in-matplotlib
        color_mapping = class_norm.mapping
        colors = [im.cmap(color_mapping[k])
                  for k in class_labels.keys()]
        labels = class_labels.values()

        # https://matplotlib.org/users/legend_guide.html
        # tag: #creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
        patches = [mpatches.Patch(color=c, label=l)
                   for c,l in zip(colors, labels)]

        ax.legend(handles=patches, bbox_to_anchor=(1, 1),
                  loc='upper right', borderaxespad=0.)
    except AttributeError:
        # class_labels not specified
        pass

# Inspired by
# https://matplotlib.org/users/colormapnorms.html#custom-normalization-two-linear-ranges
class _ClassNormalize(colors.Normalize):
    """Matplotlib colormap normalizer for a classified band.
    """
    def __init__(self, arry):
        # get unique unmasked values
        values = [v for v in np.unique(arry)
                  if not isinstance(v, np.ma.core.MaskedConstant)]

        # map unique values to points in the range 0-1
        if len(values) > 1:
            color_ticks = np.array(range(len(values)), dtype=np.float) / (len(values) - 1)
        else:
            color_ticks = np.array([0])

        self._mapping = dict((v, ct) for v, ct in zip(values, color_ticks))
        
        # Initialize base Normalize instance
        vmin = 0
        vmax = 1
        clip = False
        colors.Normalize.__init__(self, vmin, vmax, clip)
    
    def __call__(self, arry, clip=None):
        '''Create classified representation of arry for display.'''
        # round array back to ints for logical comparison
        arry = np.around(arry)
        new_arry = arry.copy()
        for k, v in self._mapping.items():
            new_arry[arry==k] = v
        return new_arry
    
    @property
    def mapping(self):
        '''property required for colors.Normalize classes
        
        We update the _mapping property in __init__ and __call__ and just
        return that property here.
        '''
        return self._mapping
    
# test out classified band visualization
test_classified_band = np.array(range(9)).reshape((3,3))
plot_classified_band(test_classified_band, title='Test Classified Band',
                     figdim=2)

# %% [markdown]
# ### Visualize UDM2 Bands
#
# The UDM2 product consists of multiple bands. The first six bands are boolean, present/absent. The seventh band is greyscale, and the eighth is the original bit-encoded UDM.

# %%
def visualize_udm2(udm2, figsize=(15,15)):
    fig, axes = plt.subplots(nrows=4, ncols=2,
                                   sharex=True, sharey=True,
                                   figsize=figsize,
                            constrained_layout=True)
    
    bands = [np.squeeze(b) for b in 
             np.split(udm2, udm2.shape[0], axis=0)]
    band_labels = udm2_labels

    fig.suptitle('UDM2 Bands', fontsize=20)
    bal = zip(bands, axes.flat, udm2_labels)
    for i, (band, ax, label) in enumerate(bal):
        unique = np.unique(band)
    
        # it is unwieldy to show a legend for more than 5 values
        if len(unique) < 5:
            class_labels = OrderedDict((v, v) for v in np.unique(band))
        else:
            class_labels = None
        imshow_class_band(ax, band, class_labels=class_labels, cmap='Greys')
        ax.set_title(label)
        ax.set_axis_off()

visualize_udm2(udm2)

# %% [markdown]
# The clear band is a combination of all of the other bands. It identifies the snow, clouds, cloud shadows, and light and heavy haze. There appears to be no heavy haze and just a touch of light haze and snow. Really, though, this is a picture of San Francisco, so light haze is possible but snow is unlikely.

# %% [markdown]
# ### Visualize UDM2 Unusable Data Mask Band
#
# The Unusable Data Mask band of the UDM2 is the original UDM. It is a bit-encoded representation of whether a pixel is usable and, if not, why. Let's check out the usability of the pixels in this image. This section pulls functionality from the [UDM notebook](udm.ipynb).

# %%
def get_udm_labels(udm):
    '''Get the interpretation of the UDM binary values'''    
    def get_label(v):
        if v == 0:
            label = 'clear'
        elif v == 1:
            label = 'blackfill'
        else:
            labels = []
            if v & int('10',2):
                labels.append('cloud')
            if v & int('1111100',2):
                bands = []
                if v & int('100',2):
                    bands.append('Blue')
                if v & int('1000', 2):
                    bands.append('Green')
                if v & int('10000', 2):
                    bands.append('Red')
                if v & int('100000', 2):
                    bands.append('Red-Edge')
                if v & int('1000000', 2):
                    bands.append('NIR')
                labels.append('missing/suspect {} data'.format(', '.join(bands)))
                
            if not len(labels):
                labels.append('{0:08b}'.format(v))

            label = ', '.join(labels)
        return label

    return OrderedDict((v, get_label(v)) for v in np.unique(udm))

udm2_udm = udm2[-1, ...]
print('Labels present in this UDM2 UDM band')
get_udm_labels(udm2_udm)
# Out:
# Labels present in this UDM2 UDM band
# OrderedDict([(0, 'clear'),
#              (1, 'blackfill'),
#              (2, 'cloud'),
#              (28, 'missing/suspect Blue, Green, Red data'),
#              (30, 'cloud, missing/suspect Blue, Green, Red data'),
#              (64, 'missing/suspect NIR data')])

# %%
def visualize_udm2_unusable(udm2, figsize=(15,15)):
    '''Visualize the unusable data mask band of the UDM2 product.'''
    fig, ax = plt.subplots(nrows=1, ncols=1,
                                   sharex=True, sharey=True,
                                   figsize=figsize)
    band = udm2[-1, :]
    label = udm2_labels[-1]

    imshow_class_band(ax, band, class_labels=get_udm_labels(band), cmap='rainbow')
    ax.set_title(label)
    ax.set_axis_off()

    plt.tight_layout()

visualize_udm2_unusable(udm2)

# %% [markdown]
# Most of the pixels within the footprint of the image are usable (purple). Most of those that aren't usable are identified as clouds (teal). Just a few pixels have suspect RGB data, likely due to saturation.

# %% [markdown]
# ## Convert UDM2 to Mask
#
# Converting the UDM2 to a binary mask is pretty straightforward. If one is just interested in only the 'clear' pixels, then they can use the first band of the UDM2 (clear band). The same can be said for avoiding 'cloud' pixels, 'haze' pixels, etc. Masking cloud and cloud shadow pixels is a little more complicated, but still pretty simple. Here, we show how to create a mask that masks all unclear pixels and how to create a mask that masks all cloud and shadow pixels.
#
# ### Mask all unclear pixels

# %%
mask_class_labels = {0: 'unmasked', 1: 'masked'}
mask_cmap = 'viridis' # looks better when just two colors are displayed

# %%
def mask_unclear(udm2_array):
    '''Create a mask from the udm2, masking all unclear pixels''' 
    return udm2_array[0,...] == 0

plot_classified_band(mask_unclear(udm2),
                     class_labels=mask_class_labels,
                     cmap=mask_cmap,
                     title='Mask All Unclear Pixels')

# %% [markdown]
# ### Mask cloud and shadow pixels

# %%
def mask_cloud_shadow(udm2_array):
    '''Create a mask from the udm2, masking all cloud and cloud shadow pixels'''
    shadow_band = udm2_array[2,...]
    cloud_band = udm2_array[5,...]
    masked_pixels = np.logical_or(shadow_band == 1, cloud_band == 1)
    return masked_pixels

plot_classified_band(mask_cloud_shadow(udm2),
                     class_labels=mask_class_labels,
                     cmap=mask_cmap,
                     title='Mask All Cloud and Shadow Pixels')
